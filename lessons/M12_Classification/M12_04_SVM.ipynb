# %% [markdown]
# # Metadata
#
# ```yaml
# Course:    DS 5001
# Module:    12 Lab
# Topic:     Classification with SVM
# Author:    R.C. Alvarado
# Date:      16 April 2023 (revised)
# ```

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_prefix = 'winereviews'
data_path = f"{data_home}/{data_prefix}/{data_prefix}"

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import plotly_express as px
from sklearn import svm

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Get Data

# %%
X_test = pd.read_pickle(f"{data_path}-X_test.csv.pickle").sort_index()
X_train = pd.read_pickle(f"{data_path}-X_train.csv.pickle").sort_index()
y_test = pd.read_pickle(f"{data_path}-y_test.csv.pickle").sort_index()
y_train = pd.read_pickle(f"{data_path}-y_train.csv.pickle").sort_index()

# %%
DOC = pd.read_csv(f"{data_path}-DOC_UNSPLIT.csv").set_index('doc_id')

# %% [markdown]
# # Training

# %%
clf = svm.LinearSVC(max_iter=1000)

# %%
clf.fit(X_train, y_train)
# Out:
# LinearSVC()

# %% [markdown]
# # Testing

# %%
y_hat = pd.DataFrame(clf.predict(X_test), index=X_test.index)

# %% [markdown]
# # Evaluation

# %%
clf.score(X_test, y_test)
# Out:
# 0.80025

# %%
RESULT = pd.concat([y_test, y_hat], axis=1)
RESULT.columns = ['doc_label', 'prediction']

# %%
RESULT['result'] = RESULT.doc_label == RESULT.prediction

# %%
RESULT.value_counts('result').plot.pie(figsize=(2,2));

# %%
RESULT.value_counts(['prediction','doc_label']).plot.pie(figsize=(2,2));

# %%
px.scatter(RESULT.join(DOC[['doc_content','points','doc_len']], how='inner').reset_index(), 'doc_len', 'points', color='result', symbol='prediction',
           height=900, width=1000, marginal_x='histogram', marginal_y='histogram')

# %%
CM = RESULT.value_counts(['prediction','doc_label']).unstack()

# %%
CM
# Out:
# doc_label      N     P
# prediction
# N           3260   855
# P            743  3142

# %%
def get_results(CM, model_id):
    
    R = pd.DataFrame(index=[model_id])
    R.index.name = 'model_id'
    
    # COUNTS
    R['TN'] = CM.iloc[0,0]   # correct rejections
    R['FN'] = CM.iloc[0,1]   # Type II errors or misses
    R['TP'] = CM.iloc[1,1]   # hits
    R['FP'] = CM.iloc[1,0]   # Type I errors or false alarms
    R['T'] = R.TP + R.TN     # All True
    R['F'] = R.FP + R.FN     # All False
    R['ALL'] = R['T'] + R.F  # All
    
    assert R.ALL.values[0] == CM.sum().sum()
    
    # RATIOS
    R['ACC'] = R['T'] / R.ALL                        # (Simple) Accuracy
    R['TPR'] = R.TP / (R.TP + R.FN)                  # Recall or Sensitivity
    R['TNR'] = R.TN / (R.TN + R.FP)                  # Specificity
    R['PPV'] = R.TP / (R.TP + R.FP)                  # Precision or Positive predictive value 
    R['BA'] = (R.TNR + R.TPR) / 2                    # Balanced Accuracy
    R['F1'] = (2 *  R.TP) / (2 * R.TP + R.FP + R.FN) # F-score where F = 1

    return R

# %%
R = get_results(CM, 'svm')

# %%
R.T.style.format(precision=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1bbaf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model_id</th>
#       <th id="T_1bbaf_level0_col0" class="col_heading level0 col0" >svm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bbaf_level0_row0" class="row_heading level0 row0" >TN</th>
#       <td id="T_1bbaf_row0_col0" class="data row0 col0" >3260.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row1" class="row_heading level0 row1" >FN</th>
#       <td id="T_1bbaf_row1_col0" class="data row1 col0" >855.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row2" class="row_heading level0 row2" >TP</th>
#       <td id="T_1bbaf_row2_col0" class="data row2 col0" >3142.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row3" class="row_heading level0 row3" >FP</th>
#       <td id="T_1bbaf_row3_col0" class="data row3 col0" >743.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row4" class="row_heading level0 row4" >T</th>
#       <td id="T_1bbaf_row4_col0" class="data row4 col0" >6402.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row5" class="row_heading level0 row5" >F</th>
#       <td id="T_1bbaf_row5_col0" class="data row5 col0" >1598.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row6" class="row_heading level0 row6" >ALL</th>
#       <td id="T_1bbaf_row6_col0" class="data row6 col0" >8000.000</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row7" class="row_heading level0 row7" >ACC</th>
#       <td id="T_1bbaf_row7_col0" class="data row7 col0" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row8" class="row_heading level0 row8" >TPR</th>
#       <td id="T_1bbaf_row8_col0" class="data row8 col0" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row9" class="row_heading level0 row9" >TNR</th>
#       <td id="T_1bbaf_row9_col0" class="data row9 col0" >0.814</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row10" class="row_heading level0 row10" >PPV</th>
#       <td id="T_1bbaf_row10_col0" class="data row10 col0" >0.809</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row11" class="row_heading level0 row11" >BA</th>
#       <td id="T_1bbaf_row11_col0" class="data row11 col0" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_1bbaf_level0_row12" class="row_heading level0 row12" >F1</th>
#       <td id="T_1bbaf_row12_col0" class="data row12 col0" >0.797</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Extract Sentiment
#
# We treat weight as valence.

# %%
SALEX = pd.DataFrame(clf.coef_, columns=X_test.columns).T.rename(columns={0:'valence'})
SALEX.index.name = 'term_str'
SALEX = SALEX.sort_values('valence')
SALEX['polarity'] = np.sign(SALEX['valence'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
SALEX['normalized'] = scaler.fit_transform(SALEX[['valence']])

# %%
SALEX.sort_values('valence', ascending=False).head(20)
# Out:
#               valence  polarity  normalized
# term_str
# 92           2.128170       1.0    1.000000
# 91           2.001256       1.0    0.943594
# filtered     1.860147       1.0    0.880879
# whipped      1.786086       1.0    0.847963
# tuck         1.756150       1.0    0.834658
# evergreen    1.755608       1.0    0.834417
# intrude      1.725813       1.0    0.821175
# explosion    1.702444       1.0    0.810789
# visible      1.697938       1.0    0.808786
# campaccio    1.694417       1.0    0.807221
# reminds      1.682179       1.0    0.801782
# glory        1.675251       1.0    0.798703
# flowing      1.673949       1.0    0.798125
# foodworthy   1.651767       1.0    0.788266
# setting      1.648987       1.0    0.787030
# january      1.634539       1.0    0.780609
# landscape    1.625316       1.0    0.776510
# sàgana       1.579523       1.0    0.756157
# charactered  1.579396       1.0    0.756101
# breakdowns   1.577309       1.0    0.755174

# %%
SALEX.sort_values('valence', ascending=True).head(20)
# Out:
#                valence  polarity  normalized
# term_str
# rossos       -2.371835      -1.0   -1.000000
# loosely      -1.839948      -1.0   -0.763606
# shortly      -1.822546      -1.0   -0.755872
# weir         -1.808759      -1.0   -0.749744
# bedell       -1.785280      -1.0   -0.739309
# tofanelli    -1.774208      -1.0   -0.734388
# flaws        -1.769431      -1.0   -0.732265
# clench       -1.739243      -1.0   -0.718848
# rosemount    -1.690797      -1.0   -0.697317
# rapid        -1.580071      -1.0   -0.648105
# complicating -1.563045      -1.0   -0.640538
# bet          -1.547848      -1.0   -0.633784
# vernaccia    -1.539996      -1.0   -0.630294
# tomatoes     -1.537530      -1.0   -0.629198
# nicer        -1.505524      -1.0   -0.614973
# milbrandt    -1.479264      -1.0   -0.603302
# moussse      -1.455156      -1.0   -0.592588
# guinjard     -1.451162      -1.0   -0.590812
# guarantees   -1.450817      -1.0   -0.590659
# acrobat      -1.430488      -1.0   -0.581624

# %%
SALEX.polarity.value_counts().plot.pie(figsize=(2,2));

# %%
SALEX.normalized.hist(bins=20);

# %%
pd.concat([SALEX.normalized.head(20),SALEX.normalized.tail(20)]).plot.barh(figsize=(5,10));

# %% [markdown]
# # Save

# %%
SALEX.to_csv(f'{data_path}-SVM_SALEX.csv')
R.to_csv(f"{data_path}-SVM_RESULT.csv", index=True)
